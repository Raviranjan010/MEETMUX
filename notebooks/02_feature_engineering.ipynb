# %% [markdown]
# # 02. Feature Engineering & Leakage Prevention
# Prepares time cyclic indicators, duration features, congestion densities, and preprocessing pipelines.

# %%
import sys
sys.path.append('../backend')
from app.ml.feature_engineering import extract_features
import pandas as pd

df = pd.read_csv('../backend/data/sample/flights.csv')
featured = extract_features(df)
featured[['flight_number', 'hour', 'is_peak_hour', 'active_flights']].head()
