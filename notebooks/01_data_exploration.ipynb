# %% [markdown]
# # 01. Airport Operations Data Exploration
# Explores historical arrival/departure patterns, taxi distributions, and meteorological correlations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('../backend/data/sample/flights.csv')
df.head()
