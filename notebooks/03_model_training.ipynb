# %% [markdown]
# # 03. Machine Learning Model Training & Evaluation Tournament
# Trains Linear Regression, Random Forest, and Gradient Boosting Regressors using a chronological 70/15/15 validation split.

# %%
import sys
sys.path.append('../backend')
from app.ml.train import train_delay_model

metadata = train_delay_model()
print('Selected Champion Model:', metadata['model_name'])
print('Metrics:', metadata['metrics'])
